# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Загрузка-и-предобработка-данных" data-toc-modified-id="Загрузка-и-предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка и предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Переименование-столбцов-и-поиск-аномалий" data-toc-modified-id="Переименование-столбцов-и-поиск-аномалий-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Переименование столбцов и поиск аномалий</a></span></li><li><span><a href="#Изменение-типов-столбцов-и-объединение-датасетов" data-toc-modified-id="Изменение-типов-столбцов-и-объединение-датасетов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение типов столбцов и объединение датасетов</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-покупателей" data-toc-modified-id="Профили-покупателей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили покупателей</a></span></li><li><span><a href="#Оплата-за-программу-лояльности" data-toc-modified-id="Оплата-за-программу-лояльности-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Оплата за программу лояльности</a></span></li><li><span><a href="#Самые-популярные-товары" data-toc-modified-id="Самые-популярные-товары-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Самые популярные товары</a></span></li><li><span><a href="#Количество-покупок" data-toc-modified-id="Количество-покупок-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Количество покупок</a></span><ul class="toc-item"><li><span><a href="#Количество-покупок-с-разбивкой-по-дням-недели" data-toc-modified-id="Количество-покупок-с-разбивкой-по-дням-недели-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Количество покупок с разбивкой по дням недели</a></span></li><li><span><a href="#Количество-покупок-с-разбивкой-по-магазинам" data-toc-modified-id="Количество-покупок-с-разбивкой-по-магазинам-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Количество покупок с разбивкой по магазинам</a></span></li></ul></li><li><span><a href="#Суммы-покупок-с-разбивкой-по-магазинам" data-toc-modified-id="Суммы-покупок-с-разбивкой-по-магазинам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Суммы покупок с разбивкой по магазинам</a></span></li><li><span><a href="#Визуализация" data-toc-modified-id="Визуализация-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Визуализация</a></span><ul class="toc-item"><li><span><a href="#Распределение-сумм-покупок-по-неделям" data-toc-modified-id="Распределение-сумм-покупок-по-неделям-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Распределение сумм покупок по неделям</a></span></li><li><span><a href="#Разбивка-выручки-от-участников-программы-лояльности" data-toc-modified-id="Разбивка-выручки-от-участников-программы-лояльности-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Разбивка выручки от участников программы лояльности</a></span></li><li><span><a href="#Средний-чек-с-разбивкой-по-дням-недели" data-toc-modified-id="Средний-чек-с-разбивкой-по-дням-недели-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Средний чек с разбивкой по дням недели</a></span></li></ul></li></ul></li><li><span><a href="#Проверка-статистических-гипотез" data-toc-modified-id="Проверка-статистических-гипотез-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка статистических гипотез</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных-к-проверке-гипотез" data-toc-modified-id="Подготовка-данных-к-проверке-гипотез-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Подготовка данных к проверке гипотез</a></span><ul class="toc-item"><li><span><a href="#Средний-чек" data-toc-modified-id="Средний-чек-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Средний чек</a></span></li><li><span><a href="#LTV" data-toc-modified-id="LTV-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>LTV</a></span></li></ul></li><li><span><a href="#Проверка-по-неотфильтрованным-данным" data-toc-modified-id="Проверка-по-неотфильтрованным-данным-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проверка по неотфильтрованным данным</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-о-среднем-чеке" data-toc-modified-id="Гипотеза-о-среднем-чеке-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Гипотеза о среднем чеке</a></span></li><li><span><a href="#Гипотеза-о-lifetime-value" data-toc-modified-id="Гипотеза-о-lifetime-value-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Гипотеза о lifetime value</a></span></li></ul></li><li><span><a href="#Проверка-по-отфильтрованным-данным" data-toc-modified-id="Проверка-по-отфильтрованным-данным-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Проверка по отфильтрованным данным</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-о-среднем-чеке" data-toc-modified-id="Гипотеза-о-среднем-чеке-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Гипотеза о среднем чеке</a></span></li><li><span><a href="#Гипотеза-о-lifetime-value" data-toc-modified-id="Гипотеза-о-lifetime-value-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Гипотеза о lifetime value</a></span></li></ul></li></ul></li><li><span><a href="#Вывод-и-рекомендации-для-заказчика" data-toc-modified-id="Вывод-и-рекомендации-для-заказчика-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод и рекомендации для заказчика</a></span></li></ul></div>

# %% [markdown]
# ## Введение
#
# **Название проекта:** \
# Анализ программы лояльности магазина строительных товаров.
#
# **Описание проекта:** \
# На анализ предоставлены данные о покупках в магазине строительных материалов «Строили, строили и наконец построили». Все покупатели могут получить доступ в магазин с использованием персональных карт. За 200 рублей в месяц они могут стать участниками программы лояльности. В программу включены скидки, специальные предложения, подарки.
#
# **Цели проекта:** \
# Нам предстоит изучить:
# - портрет покупателя
# - количество покупок, выручку, средний чек, LTV
# - различаются ли средние чеки и LTV покупателей участников и неучастников программы лояльности.
#
# Чтобы в итоге у нас получилось:
# - сделать вывод, на основе которого будет принято решение о сокращении или расширении программы лояльности.
# - сформулировать рекомендации для менеджера программы лояльности.
#
# **Исходные данные:** \
# `retail_dataset.csv` - содержит основные данные о покупках в строительном магазине. `product_codes.csv` - содержит коды товаров и их цены.
#
# **План анализа данных:**
# 1. Подготовить исходные данные к анализу.
# 2. Посмотреть на портрет нашего покупателя.
# 3. Посчитать количество покупок, выручку, средний чек, LTV
# 4. Проверить статистические гипотезы.
# 5. Сформулировать выводы и рекомендации для менеджера программы лояльности.

# %% [markdown]
# ## Загрузка и предобработка данных

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from scipy import stats
from datetime import datetime, timedelta
import warnings

# %% [markdown]
# Присвоим датасеты переменным

# %%
df = pd.read_csv('https://code.s3.yandex.net/datasets/retail_dataset.csv')
codes = pd.read_csv('https://code.s3.yandex.net/datasets/product_codes.csv')

# %% [markdown]
# Посмотрим на данные

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105335 entries, 0 to 105334
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   purchaseid       105335 non-null  object
#  1   item_ID          105335 non-null  object
#  2   Quantity         105335 non-null  int64
#  3   purchasedate     105335 non-null  object
#  4   CustomerID       69125 non-null   float64
#  5   ShopID           105335 non-null  object
#  6   loyalty_program  105335 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 5.6+ MB

# %%
df.head(5)
# Out:
#   purchaseid item_ID  Quantity         purchasedate  CustomerID  ShopID  \
# 0     538280   21873        11  2016-12-10 12:50:00     18427.0  Shop 0
# 1     538862   22195         0  2016-12-14 14:11:00     22389.0  Shop 0
# 2     538855   21239         7  2016-12-14 13:50:00     22182.0  Shop 0
# 3     543543   22271         0  2017-02-09 15:33:00     23522.0  Shop 0
# 4     543812   79321         0  2017-02-13 14:40:00     23151.0  Shop 0
#
#    loyalty_program
# 0              0.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0

# %%
codes.head(5)
# Out:
#   productID  price_per_one
# 0    85123A           2.55
# 1     71053           3.39
# 2    84406B           2.75
# 3    84029G           3.39
# 4    84029E           3.39

# %% [markdown]
# ### Переименование столбцов и поиск аномалий

# %% [markdown]
# Переименуем колонки

# %%
#делаем все названия строчными
df.columns = map(str.lower, df.columns)

# %%
df = df.rename(columns={'purchaseid': 'purchase_id',
                        'purchasedate': 'date',
                        'customerid': 'user_id',
                        'shopid': 'shop_id',
                        'loyalty_program': 'promo'
                       })

# %%
codes = codes.rename(columns={'productID':'item_id',
                              'price_per_one': 'item_price'})

# %% [markdown]
# Поищем аномалии в данных покупок

# %%
print("Количество полных дубликатов:", df.duplicated().sum())
print("Доля от общего датасета", round(df.duplicated().sum() / len(df) * 100, 2), '%')
print()
print("Количество неизвестных покупателей", df['user_id'].isna().sum())
print("Доля от общего датасета", round(df['user_id'].isna().sum() / len(df) * 100, 2), '%')
print()
print("Количество отрицательных значений проданных товаров:", len(df[df['quantity'] < 0]))
print("Доля от общего датасета", round(len(df[df['quantity'] < 0]) / len(df) * 100, 2), '%')
print()
print("Количество нулевых значений проданных товаров:", len(df[df['quantity'] == 0]))
print("Доля от общего датасета", round(len(df[df['quantity'] == 0]) / len(df) * 100, 2), '%')
# Out:
# Количество полных дубликатов: 1033
# Доля от общего датасета 0.98 %
#
# Количество неизвестных покупателей 36210
# Доля от общего датасета 34.38 %
#
# Количество отрицательных значений проданных товаров: 2118
# Доля от общего датасета 2.01 %
#
# Количество нулевых значений проданных товаров: 33055
# Доля от общего датасета 31.38 %

# %% [markdown]
# Работа с аномалиями:
# - Дубликаты и отрицательные значения проданных товаров мы можем легко убрать, их не так много.
# - Неизвестных покупателей мы не будем трогать, потому что они пригодятся нам для рассчета среднего чека.
# - Нулевые значения проданных товаров тоже придется убрать, несмотря на то, что их так много. Потому что мы не знаем сколько реально было продано товара, и других данных об этом у нас нет.

# %%
#сохраним старый датасет
old_df = df.copy()
#полные дубликаты
df = df.drop_duplicates().reset_index(drop=True)
#отрицательные и нулевые значения проданных товаров
df = df.drop(df[df['quantity'] <= 0].index).reset_index(drop=True)

# %%
print("Осталось от первоначального датасета:", round(len(df) / len(old_df) * 100, 2), '%')
# Out:
# Осталось от первоначального датасета: 66.33 %

# %% [markdown]
# С аномалиями в датасете покупок закончили.
#
# Поищем аномалии в данных по ценах

# %%
#уникальные товары в датасете покупок
print(old_df['item_id'].nunique())
#уникальные товары в датасете цен
print(codes['item_id'].nunique())
#всего строчек в датасете цен
print(len(codes['item_id']))
# Out:
# 3159
# 3159
# 9969

# %% [markdown]
# Видим, что цен намного больше, чем уникальных товаров. Проверим дубликаты

# %%
codes.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет. Проверим сколько товаров больше чем с одной ценой.

# %%
temp_var = (
    codes
    .groupby('item_id')
    .agg({'item_price':'nunique'})
    .sort_values(by='item_price', ascending=False)
)
print(temp_var[temp_var['item_price'] > 1].count())
display(temp_var.head(5))
# Out:
# item_price    2494
# dtype: int64
#          item_price
# item_id
# DOT             174
# M                59
# S                29
# POST             15
# D                13

# %% [markdown]
# Видим, что у 2494 товаров из 3159 товаров указано как минимум две цены. У нас нет информации, ни о том, что это за товары, ни о том, какую из цен считать более верной. Поэтому возьмем среднюю цену каждого товара

# %%
codes = (
    codes
    .groupby('item_id')
    .agg({'item_price':'mean'})
)
codes = codes.reset_index()
codes['item_price'] = round(codes['item_price'], 2)

# %% [markdown]
# **Вывод:**
# - Нам пришлось избавиться от трети данных, но мы все равно не сможем никак их использовать.
# - Мы взяли среднюю цену каждого товара, где встречалось несколько вариантов цен, потому что не знаем какая на самом деле цена.

# %% [markdown]
# ### Изменение типов столбцов и объединение датасетов

# %% [markdown]
# Изменим тип данных столбцов на более подходящий

# %%
#дата и время
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
#целые числа
df['user_id'] = df['user_id'].astype('Int64') # с большой буквы, чтобы оставить NaN
df['promo'] = df['promo'].astype('int64')

# %% [markdown]
# Сделаем внешнее соединение двух таблиц, чтобы не потерять данные

# %%
#сохраним данные, в итоге у нас есть retail и codes
retail = df.copy()

# %%
df = df.merge(
    codes,
    how='inner',
    on='item_id',
    suffixes=('_retail', '_codes'),
    copy=True,
    indicator=True #индикатор создает столбец _merge, где указано в каких датасетах есть эта строчка
)

# %% [markdown]
# Проверим есть ли в данных строчки, которые оказались только в одном датасете

# %%
df[df['_merge'] != 'both']
# Out:
# Empty DataFrame
# Columns: [purchase_id, item_id, quantity, date, user_id, shop_id, promo, item_price, _merge]
# Index: []

# %% [markdown]
# Таких строчек нет, поэтому мы избавимся от вспомогательных столбцов и продолжим работу с одним датасетом

# %%
df = df.drop('_merge', axis=1)

# %%
df.head(5)
# Out:
#   purchase_id item_id  quantity                date  user_id shop_id  promo  \
# 0      538280   21873        11 2016-12-10 12:50:00    18427  Shop 0      0
# 1      540418   21873         1 2017-01-07 11:04:00     <NA>  Shop 0      0
# 2      541516   21873         2 2017-01-18 17:34:00     <NA>  Shop 0      0
# 3      541566   21873        35 2017-01-19 11:50:00    23401  Shop 0      1
# 4      538843   21873         1 2016-12-14 13:18:00    21712  Shop 0      0
#
#    item_price
# 0        1.81
# 1        1.81
# 2        1.81
# 3        1.81
# 4        1.81

# %% [markdown]
# ## Исследовательский анализ данных
# Подготовим профили покупателей, с информацией:
# - Состоит ли в программе лояльности
# - Первая покупка
# - Частота и количество покупок

# %% [markdown]
# ### Профили покупателей

# %% [markdown]
# Для удобства, добавим еще несколько столбцов:
# - Стоимость покупки
# - Неделя покупки с обозначением даты
# - Месяц с обозначением года
# - День недели

# %%
df['item_total_price'] = df.quantity * df.item_price
df['week'] = df["date"].dt.to_period("W")
df['month'] = df["date"].dt.to_period("M")
df['weekday'] = df["date"].dt.dayofweek

# %% [markdown]
# Посчитаем средний чек (сначала **полный** чек на каждую покупку, а потом средний чек на каждого покупателя)

# %%
#чек на каждую покупку
temp_var = ( #временная переменная
    df
    .groupby('purchase_id')
    .agg({'item_total_price': 'sum'})
    .rename(columns={'item_total_price': 'purchase_price'})
)
temp_var = temp_var.reset_index()
#добавим чек на каждую покупку в наш датасет
df = df.merge(
    temp_var,
    on='purchase_id',
    how='left'
)

# %% [markdown]
# Посмотрим, что получилось

# %%
df.sort_values(by='purchase_id').head(5)
# Out:
#       purchase_id item_id  quantity                date  user_id shop_id  \
# 4830       536365  85123A         5 2016-12-01 08:26:00    23529  Shop 0
# 13853      536365  84029G         5 2016-12-01 08:26:00    23529  Shop 0
# 62568      536365   21730         5 2016-12-01 08:26:00    23529  Shop 0
# 16586      536365  84406B         7 2016-12-01 08:26:00    23529  Shop 0
# 22243      536365   22752         1 2016-12-01 08:26:00    23529  Shop 0
#
#        promo  item_price  item_total_price                   week    month  \
# 4830       1        3.41             17.05  2016-11-28/2016-12-04  2016-12
# 13853      1        6.50             32.50  2016-11-28/2016-12-04  2016-12
# 62568      1        7.33             36.65  2016-11-28/2016-12-04  2016-12
# 16586      1        4.25             29.75  2016-11-28/2016-12-04  2016-12
# 22243      1       12.44             12.44  2016-11-28/2016-12-04  2016-12
#
#        weekday  purchase_price
# 4830         3          184.49
# ...

# %% [markdown]
# Создадим профили пользователей и посчитаем средний чек на каждого

# %%
#создаем профили покупателей
profiles = (
    df
    .groupby('user_id')
    .agg({'date': ['first', 'nunique'], #дата первой покупки и количество уникальных покупок
          'item_total_price': 'sum', #lifetime value 
          'purchase_price': 'mean' #средний чек покупателя
         })
)
#убираем мультииндекс
profiles.columns = profiles.columns.droplevel()
#делаем user_id обратно колонкой
profiles = profiles.reset_index()
#переименовываем колонки
profiles = profiles.rename(columns={'first': 'first_dt',
                                    'nunique': 'purchase_count',
                                    'sum': 'ltv',
                                    'mean': 'mean_check'
                                   })
#округляем
profiles['mean_check'] = round(profiles['mean_check'], 2)

# %% [markdown]
# Добавим маркер участника программы лояльности

# %%
#добавляем указание участника программы лояльности
temp_var = ( #временная переменная
    df
    .groupby(['user_id', 'promo'])
    .agg({'quantity': 'sum'})
)
temp_var = temp_var.reset_index()
#соединяем датасеты
profiles = profiles.merge( 
    temp_var[['user_id', 'promo']], 
    on='user_id',
    how='left'
)

# %%
profiles.head(5)
# Out:
#    user_id            first_dt  purchase_count       ltv  mean_check  promo
# 0    18025 2017-01-18 10:01:00               1  77182.56    77182.56      0
# 1    18026 2017-01-26 14:30:00               2   1718.41      862.87      0
# 2    18027 2016-12-16 19:09:00               2   1852.44     1217.63      0
# 3    18029 2017-02-02 16:01:00               1    385.18      385.18      0
# 4    18031 2017-02-16 12:33:00               1    370.64      370.64      0

# %% [markdown]
# **Вывод:** У нас получились профили пользователей со средним чеком и LTV, которые пригодятся нам для проверки гипотез.

# %% [markdown]
# ### Оплата за программу лояльности

# %% [markdown]
# Для того, чтобы посчитать, сколько заплатили участники программы лояльности за участие в ней, посмотрим на промежуток дат, в которые происходили покупки.

# %%
print("Дата начала:", df.date.min())
print("Дата окончания:", df.date.max())
print("Всего дней:", df.date.max() - df.date.min())
# Out:
# Дата начала: 2016-12-01 08:26:00
# Дата окончания: 2017-02-28 17:01:00
# Всего дней: 89 days 08:35:00

# %% [markdown]
# У нас на три полных месяца приходится 90 дней. Допустим, что покупатель, участвующий в акции, платит за участие каждые 30 дней.
#
# Добавим количество дней, которое покупатель участвует в акции

# %%
#сохраним старую переменную
old_profiles = profiles.copy()

# %%
profiles = (profiles
            #сначала делаем вспомогательный столбец
            .assign(promo_days_1=lambda x: df.date.max() - x.first_dt,
            #чтобы из него получить количество дней в формате числа
                    promo_days=lambda x: x.promo_days_1.dt.days)
            #и избавляемся от него
            .drop(columns={'promo_days_1'})
           )

# %%
#прописываем условия
conditions = [
    profiles['promo'].eq(0),
    profiles['promo'].eq(1) & profiles['promo_days'].isin(range(1, 31)),
    profiles['promo'].eq(1) & profiles['promo_days'].isin(range(31, 61)),
    profiles['promo'].eq(1) & profiles['promo_days'].isin(range(61, 91)),
]
#прописываем варианты выбора
choices = [0, 200, 400, 600]
#получаем колонку со значением, сколько заплатил покупатель за участие в акции
profiles['promo_value'] = np.select(conditions, choices, default=0)
#прибавляем к ltv значение выше
profiles['ltv'] = profiles['ltv'] + profiles['promo_value']

# %%
profiles.tail(5)
# Out:
#       user_id            first_dt  purchase_count      ltv  mean_check  promo  \
# 1666    23936 2017-02-16 15:13:00               2   640.34      371.43      1
# 1667    23938 2016-12-08 13:38:00               1  1111.40      511.40      1
# 1668    23939 2016-12-16 18:23:00               2  1554.06      583.18      1
# 1669    23948 2016-12-08 13:53:00               1   797.50      197.50      1
# 1670    23962 2017-01-06 14:14:00               3   501.97       41.65      1
#
#       promo_days  promo_value
# 1666          12          200
# 1667          82          600
# 1668          73          600
# 1669          82          600
# 1670          53          400

# %% [markdown]
# **Примечание:**
# - LTV будет или стоять на месте или расти, его нет смысла по датам показывать в презентации, только в дашборде.
# - Единственная визуализация, которую здесь вижу - это абсолютные цифры чеков c разбивкой на участников/неучастников программы лояльности (например) за каждую неделю проведения акции. Можно еще выделить отдельно сколько заработали на оплату за программу лояльности.

# %% [markdown]
# ### Самые популярные товары

# %% [markdown]
# Разделим датасет на два -  с покупателями с картой лояльности и без нее. Будем использовать эти два датасета для сравнений в будущем

# %%
non_loyalty = df[df['promo'] == 0]
loyalty = df[df['promo'] == 1]

# %%
df.head(3)
# Out:
#   purchase_id item_id  quantity                date  user_id shop_id  promo  \
# 0      538280   21873        11 2016-12-10 12:50:00    18427  Shop 0      0
# 1      540418   21873         1 2017-01-07 11:04:00     <NA>  Shop 0      0
# 2      541516   21873         2 2017-01-18 17:34:00     <NA>  Shop 0      0
#
#    item_price  item_total_price                   week    month  weekday  \
# 0        1.81             19.91  2016-12-05/2016-12-11  2016-12        5
# 1        1.81              1.81  2017-01-02/2017-01-08  2017-01        5
# 2        1.81              3.62  2017-01-16/2017-01-22  2017-01        2
#
#    purchase_price
# 0         1052.98
# 1         1770.00
# 2          798.39

# %%
#покупатели с картой
item_popularity_l = (
    loyalty
    .groupby('item_id')
    .agg({'quantity': 'sum',
          'purchase_price': 'sum'})
    .reset_index()
)

# %%
#покупатели без карты
item_popularity_n = (
    non_loyalty
    .groupby('item_id')
    .agg({'quantity': 'sum',
          'purchase_price': 'sum'})
    .reset_index()
)

# %%
#количество товаров
item_popularity_quantity_n = item_popularity_n.sort_values(by='quantity', ascending=False).head(20)
item_popularity_quantity_l = item_popularity_l.sort_values(by='quantity', ascending=False).head(20)
#сумма проданного
item_popularity_quality_n = item_popularity_n.sort_values(by='purchase_price', ascending=False).head(20)
item_popularity_quality_l = item_popularity_l.sort_values(by='purchase_price', ascending=False).head(20)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)

#рисунок 1
axes[0].bar(item_popularity_quantity_n['item_id'],
               item_popularity_quantity_n['quantity'])

#рисунок 2
axes[0].bar(item_popularity_quantity_l['item_id'],
               item_popularity_quantity_l['quantity'])
axes[0].yaxis.set_major_locator(ticker.MultipleLocator(10000))
axes[0].set_title('Количество проданного товара', fontsize=16)
axes[0].set_ylabel('')
axes[0].set_xlabel('Номер товара')
axes[0].grid()
axes[0].legend(title='Программа лояльности', labels=['Нет', 'Да'])
plt.setp(axes[0].xaxis.get_majorticklabels(), rotation=45)

#рисунок 3
axes[1].bar(item_popularity_quality_n['item_id'],
               item_popularity_quality_n['purchase_price'])


#рисунок 4
axes[1].bar(item_popularity_quality_l['item_id'],
               item_popularity_quality_l['purchase_price'])
axes[1].yaxis.set_major_locator(ticker.MultipleLocator(50000))
axes[1].set_title('Сумма проданного', fontsize=16)
axes[1].set_ylabel('')
axes[1].set_xlabel('Номер товара')
axes[1].grid()
axes[1].legend(title='Программа лояльности', labels=['Нет', 'Да'])
plt.setp(axes[1].xaxis.get_majorticklabels(), rotation=45)

plt.subplots_adjust(hspace=0.4)
fig.set_figwidth(15)
fig.set_figheight(12)
plt.show()

# %% [markdown]
# **Вывод:**
# - К сожалению, набор цифр вместо названия тяжело воспринимать на любом графике. Поэтому эти графики вряд ли попадут в презентацию, но они очень показательны с точки зрения редкого пересечения количества проданного и суммы (чеков) проданного товара.
# - Товарные позиции, в которые наиболее популярны и среди участников программы и среди других покупателей:
#     1. 85123A
#     2. 85099B
#     3. 22469
#     4. 22423
#     5. 22720

# %% [markdown]
# ### Количество покупок

# %% [markdown]
# #### Количество покупок с разбивкой по дням недели

# %%
#покупатели без карты
purchase_cnt_by_weekday_n = (
    non_loyalty
    .groupby(df.weekday)
    .agg({'purchase_id': 'count'})
    .rename(columns={'purchase_id': 'purchases'})
)

# %%
#покупатели с картой
purchase_cnt_by_weekday_l = (
    loyalty
    .groupby(df.weekday)
    .agg({'purchase_id': 'count'})
    .rename(columns={'purchase_id': 'purchases'})
)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2) # фигура в две строчки и две колонки
axes[0, 0].pie(purchase_cnt_by_weekday_n['purchases'],
            labels=['ПН', 'ВТ', 'СР', 'ЧТ', 'ПТ', 'СБ'],
            startangle=90,
            counterclock=False,
            autopct=lambda p: '{:.0f}'.format(p * purchase_cnt_by_weekday_n['purchases'].sum() / 100)
      )

axes[0, 1].pie(purchase_cnt_by_weekday_n['purchases'],
            labels=['ПН', 'ВТ', 'СР', 'ЧТ', 'ПТ', 'СБ'],
            startangle=90,
            counterclock=False,
            autopct=lambda x: '{:.2f}%'.format(x),
      )
axes[1, 0].pie(purchase_cnt_by_weekday_l['purchases'],
            labels=['ПН', 'ВТ', 'СР', 'ЧТ', 'ПТ', 'СБ'],
            startangle=90,
            counterclock=False,
            autopct=lambda p: '{:.0f}'.format(p * purchase_cnt_by_weekday_l['purchases'].sum() / 100)
      )

axes[1, 1].pie(purchase_cnt_by_weekday_l['purchases'],
            labels=['ПН', 'ВТ', 'СР', 'ЧТ', 'ПТ', 'СБ'],
            startangle=90,
            counterclock=False,
            autopct=lambda x: '{:.2f}%'.format(x),
      )

axes[0, 0].set_title('Количество покупок по дням без карты')
axes[0, 1].set_title('Процент покупок по дням без карты')
axes[1, 0].set_title('Количество покупок по дням с картой')
axes[1, 1].set_title('Процент покупок по дням с картой')
fig.set_figwidth(15)
fig.set_figheight(12)
plt.show()

# %% [markdown]
# **Вывод:** По графику видим, что покупатели с картой равномернее распределяются по дням недели, но кроме этого сложно как-то интерпретировать эти данные.

# %% [markdown]
# #### Количество покупок с разбивкой по магазинам

# %%
#покупатели с картой
purchase_cnt_by_shop_l = (
    loyalty
    .groupby(df.shop_id)
    .agg({'purchase_id': 'count'})
    .rename(columns={'purchase_id': 'purchases'})
    .reset_index()
    .sort_values(by='purchases', ascending=False)
)

# %%
#покупатели без карты
purchase_cnt_by_shop_n = (
    non_loyalty
    .groupby(df.shop_id)
    .agg({'purchase_id': 'count'})
    .rename(columns={'purchase_id': 'purchases'})
    .reset_index()
    .sort_values(by='purchases', ascending=False)
)

# %% [markdown]
# Так как магазинов целых 30, но один занимает 90%, оставим его, а остальные сгруппируем вместе

# %%
new_row = {'shop_id':'Other', 'purchases':purchase_cnt_by_shop_n.purchases.tail(29).sum()}
purchase_cnt_by_shop_n = purchase_cnt_by_shop_n.append(new_row, ignore_index=True)
new_row = {'shop_id':'Other', 'purchases':purchase_cnt_by_shop_l.purchases.tail(3).sum()}
purchase_cnt_by_shop_l = purchase_cnt_by_shop_l.append(new_row, ignore_index=True)

# %%
#удалим строчки по индексам
purchase_cnt_by_shop_l = purchase_cnt_by_shop_l.drop(index=list(range(1,4)))
purchase_cnt_by_shop_n = purchase_cnt_by_shop_n.drop(index=list(range(1,30)))

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2)
axes[0, 0].pie(purchase_cnt_by_shop_n['purchases'],
            labels=['Shop 0', 'Other'],
            startangle=90,
            counterclock=False,
            autopct=lambda p: '{:.0f}'.format(p * purchase_cnt_by_shop_n['purchases'].sum() / 100),
            pctdistance=0.8,
            explode=[0.05]*2
      )
axes[0, 1].pie(purchase_cnt_by_shop_n['purchases'],
            labels=['Shop 0', 'Other'],
            startangle=90,
            counterclock=False,
            autopct=lambda x: '{:.2f}%'.format(x),
            pctdistance=0.8,
            explode=[0.05]*2
      )
axes[1, 0].pie(purchase_cnt_by_shop_l['purchases'],
            labels=['Shop 0', 'Other'],
            startangle=90,
            counterclock=False,
            autopct=lambda p: '{:.0f}'.format(p * purchase_cnt_by_shop_l['purchases'].sum() / 100),
            pctdistance=0.8,
            explode=[0.05]*2
      )
axes[1, 1].pie(purchase_cnt_by_shop_l['purchases'],
            labels=['Shop 0', 'Other'],
            startangle=90,
            counterclock=False,
            autopct=lambda x: '{:.2f}%'.format(x),
            pctdistance=0.8,
            explode=[0.05]*2
      )
axes[0, 0].set_title('Количество покупок по магазинам без карты')
axes[0, 1].set_title('Процент покупок по магазинам без карты')
axes[1, 0].set_title('Количество покупок по магазинам с картой')
axes[1, 1].set_title('Процент покупок по магазинам с картой')
fig.set_figwidth(15)
fig.set_figheight(15)
plt.show()

# %% [markdown]
# **Вывод**: Видим, что большинство покупателей приходят в один магазин, а с картой вообще 99% покупок совершают в нем.

# %% [markdown]
# ### Суммы покупок с разбивкой по магазинам
#
# Посмотрим теперь на суммы покупок магазинов. Возьмем топ-5 лидеров.

# %%
purchase_sum_by_shop = (
    df
    .groupby(df.shop_id)
    .agg({'purchase_price': 'sum'})
    .rename(columns={'purchase_price': 'purchases'})
    .sort_values(by='purchases', ascending=False)
)

# %%
purchase_sum_by_shop_l = (
    loyalty
    .groupby(df.shop_id)
    .agg({'purchase_price': 'sum'})
    .rename(columns={'purchase_price': 'purchases'})
    .reset_index()
    .sort_values(by='purchases', ascending=False)
)

# %%
purchase_sum_by_shop_n = (
    non_loyalty
    .groupby(df.shop_id)
    .agg({'purchase_price': 'sum'})
    .rename(columns={'purchase_price': 'purchases'})
    .reset_index()
    .sort_values(by='purchases', ascending=False)
)

# %%
new_row = {'shop_id':'Other', 'purchases':purchase_sum_by_shop.purchases.tail(25).sum()}
purchase_sum_by_shop = purchase_sum_by_shop.append(new_row, ignore_index=True)
new_row = {'shop_id':'Other', 'purchases':purchase_sum_by_shop_n.purchases.tail(29).sum()}
purchase_sum_by_shop_n = purchase_sum_by_shop_n.append(new_row, ignore_index=True)

new_row = {'shop_id':'Other', 'purchases':purchase_sum_by_shop_l.purchases.tail(3).sum()}
purchase_sum_by_shop_l = purchase_sum_by_shop_l.append(new_row, ignore_index=True)

# %%
#удалим строчки по индексам
purchase_sum_by_shop = purchase_sum_by_shop.drop(index=list(range(5,31)))
purchase_sum_by_shop_l = purchase_sum_by_shop_l.drop(index=list(range(1,4)))
purchase_sum_by_shop_n = purchase_sum_by_shop_n.drop(index=list(range(5,30)))

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2)
axes[0, 0].pie(purchase_sum_by_shop_n['purchases'],
            startangle=90,
            counterclock=False,
            autopct=lambda p: '{:.0f}'.format(p * purchase_sum_by_shop_n['purchases'].sum() / 100),
            pctdistance=1.15,
            explode=[0.05]*6
           )
axes[0, 1].pie(purchase_sum_by_shop_n['purchases'],
            startangle=90,
            counterclock=False,
            autopct=lambda x: '{:.2f}%'.format(x),
            pctdistance=1.15,
            explode=[0.05]*6
      )
axes[1, 0].pie(purchase_sum_by_shop_l['purchases'],
            startangle=90,
            counterclock=False,
            autopct=lambda p: '{:.0f}'.format(p * purchase_sum_by_shop_l['purchases'].sum() / 100),
            pctdistance=1.1,
            explode=[0.05]*2
           )
axes[1, 1].pie(purchase_sum_by_shop_l['purchases'],
            startangle=90,
            counterclock=False,
            autopct=lambda x: '{:.2f}%'.format(x),
            pctdistance=1.1,
            explode=[0.05]*2
      )

axes[0, 0].set_title('Сумма покупок по магазинам без карты')
axes[0, 0].legend(labels=['Shop 0', 'Shop 3', 'Shop 6', 'Shop 2', 'Shop 4', 'Other'])
axes[0, 1].set_title('Процент суммы покупок по магазинам без карты')
axes[0, 1].legend(labels=['Shop 0', 'Shop 3', 'Shop 6', 'Shop 2', 'Shop 4', 'Other'])
axes[1, 0].set_title('Сумма покупок по магазинам с картой')
axes[1, 0].legend(labels=['Shop 0', 'Other'])
axes[1, 1].set_title('Процент суммы покупок по магазинам с картой')
axes[1, 1].legend(labels=['Shop 0', 'Other'])
fig.set_figwidth(15)
fig.set_figheight(15)
plt.show()

# %% [markdown]
# **Вывод:** Подтверждаем, большинство сумм покупок происходит в одном магазине, и участники акции также почти не пользуются другими магазинами.

# %% [markdown]
# ### Визуализация

# %% [markdown]
# #### Распределение сумм покупок по неделям

# %% [markdown]
# Сводная таблица для удобства визуализации

# %%
purchase_pivot = df.pivot_table(
    index=['promo', 'week'],
    values=['item_total_price'],
    aggfunc=['sum']
)
purchase_pivot.columns = purchase_pivot.columns.droplevel()
purchase_pivot = purchase_pivot.reset_index()
purchase_pivot = purchase_pivot.sort_values(by=['promo', 'week'])

# %%
purchase_pivot.loc[purchase_pivot.promo == 1, 'promo'] = 'Да'
purchase_pivot.loc[purchase_pivot.promo == 0, 'promo'] = 'Нет'

# %%
warnings.filterwarnings("ignore")

# %%
fig, ax = plt.subplots(figsize=(15, 5))  
g = sns.barplot(ax=ax,
                x='week',
                y='item_total_price',
                hue='promo',
                data=purchase_pivot)

g.legend(bbox_to_anchor=(1, 1), ncol=1, title='Программа лояльности')
ylabels = ['{:,.0f}'.format(x) + 'K' for x in g.get_yticks()/1000]
g.set_yticklabels(ylabels)
g.set(xlabel='Начало и конец недели', ylabel='Сумма покупок')
g.set_title('Распределение сумм покупок по неделям')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Вывод:** Сравнивать абсолютные доходы от покупателей двух групп нет смысла.

# %% [markdown]
# #### Разбивка выручки от участников программы лояльности

# %% [markdown]
# Посмотрим на визуализацию того, сколько процентов нашей выручки в период программы лояльности занимает оплата за нее

# %%
fig, ax = plt.subplots()
# рисунок 2
ax.pie([round(sum(profiles['promo_value']) / sum(profiles[profiles['promo'] == 1]['ltv']) * 100, 2),
             round((sum(profiles[profiles['promo'] == 1]['ltv'])) / sum(profiles.ltv) * 100, 2)],
            labels=['Подписка', 'Выручка'],
            autopct=lambda x: '{:.2f}%'.format(x),
            startangle=90
       )
ax.set(title='Отношение выручки и оплаты программы')
fig.set_figwidth(15)
fig.set_figheight(5)
plt.show()

# %% [markdown]
# **Вывод:** Вот тут очень хорошо видно, что **42% выручки** среди участников программы лояльности составляет оплата за участие в программе лояльности. Я бы включил это в презентацию для менеджера, как свидетельство успешности программы лояльности.

# %% [markdown]
# #### Средний чек с разбивкой по дням недели

# %%
mean_check_loyalty = (
    loyalty
    .groupby(df.weekday)
    .agg({'purchase_price': 'mean'})
    .rename(columns={'purchase_price': 'mean_price'})
)

# %%
mean_check_non_loyalty = (
    non_loyalty
    .groupby(df.weekday)
    .agg({'purchase_price': 'mean'})
    .rename(columns={'purchase_price': 'mean_price'})
)

# %%
fig, ax = plt.subplots(figsize=(15, 5)) 
ax.plot(mean_check_loyalty, label='Да')
ax.plot(mean_check_non_loyalty, label='Нет')
ax.set_xticklabels(labels=['f', 'ПН', 'ВТ', 'СР', 'ЧТ', 'ПТ', 'СБ'])
ax.grid()
ax.legend(title='Программа лояльности')
plt.show()

# %% [markdown]
# **Вывод:** график средних чеков по дням ничего не дает

# %% [markdown]
# ## Проверка статистических гипотез
# Сформулируйте и проверьте статистические гипотезы.
# - Проверьте гипотезу: средний чек участников программы лояльности выше, чем у остальных покупателей.
# - Сформулируйте собственную статистическую гипотезу. Дополните её нулевой и альтернативной гипотезами. Проверьте гипотезу с помощью статистического теста.

# %% [markdown]
# Вторая гипотеза, которую я бы рассмотрел, звучит так: lifetime value участников программы лояльности выше, чем у остальных покупателей. Так как у нас нет расходов на привлечение и есть только цифры выручки, я бы еще попробовал прибавить ещемесячную оплату из 200 рублей к lifetime value.  Итого имеем две нулевых и две альтернативных гипотезы:
# 1. Гипотеза о среднем чеке
#     - $H_{0}$: Между чеками участников программы лояльности и остальными покупателями **нет** значимой разницы.
#     - $H_{1}$: Между чеками участников программы лояльности и остальными покупателями **есть** значимая разница.
# 2. Гипотеза о lifetime value
#     - $H_{0}$: Между lifetime value участников программы лояльности и остальными покупателями **нет** значимой разницы.
#     - $H_{1}$: Между lifetime value  участников программы лояльности и остальными покупателями **есть** значимая разница.

# %% [markdown]
# ### Подготовка данных к проверке гипотез

# %% [markdown]
# #### Средний чек

# %% [markdown]
# Посмотрим на график распределения средних чеков, чтобы выявить аномалии.

# %%
plt.scatter(y=profiles.index, x=profiles.mean_check, alpha=0.3, s=10)
plt.show()

# %% [markdown]
# Узнаем перцентили, чтобы избавиться от аномалий.

# %%
print(np.percentile(profiles['mean_check'], [95, 99]))
# Out:
# [1802.825 5115.155]

# %% [markdown]
# Отбросим все, что больше 95 перцентиля

# %%
#создаем фильтр
query_column = profiles.mean_check
query_variable = 5112
profiles_check = profiles.query('@query_column < @query_variable')

# %%
#неотфильтрованные данные
sample_check_0 = profiles[profiles['promo'] == 0]['mean_check']
sample_check_1 = profiles[profiles['promo'] == 1]['mean_check']

# %%
#отфильтрованные данные
filtered_sample_check_0 = profiles_check[profiles_check['promo'] == 0]['mean_check']
filtered_sample_check_1 = profiles_check[profiles_check['promo'] == 1]['mean_check']

# %% [markdown]
# Посмотрим как это выглядит

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)
#покупатели без карты лояльности
axes[0].scatter(y=profiles[profiles['promo'] == 0].index,
           x=profiles[profiles['promo'] == 0].mean_check,
           alpha=0.5, s=10)
#линия среднего
axes[0].axvline(x=round(sample_check_0.mean(), 2), color='red', linestyle='--')
axes[0].axvline(x=round(filtered_sample_check_0.mean(), 2), color='pink', linestyle='--')

#покупатели с картой лояльности
axes[1].scatter(y=profiles[profiles['promo'] == 1].index,
           x=profiles[profiles['promo'] == 1].mean_check,
           alpha=0.5, s=10)
#линия среднего
axes[1].axvline(x=round(sample_check_1.mean(), 2), color='red', linestyle='--')
axes[1].axvline(x=round(filtered_sample_check_1.mean(), 2), color='pink', linestyle='--')

axes[0].grid(visible=True)
axes[0].set_xlim([0, 1803]) #ограничиваем, чтобы график был читаемым
axes[0].set(title='Средний чек без карты лояльности')
axes[0].xaxis.set_major_locator(ticker.MultipleLocator(100))
axes[0].get_yaxis().set_visible(False) #прячем id пользователей, они нам не нужны

axes[1].grid(visible=True)
axes[1].set_xlim([0, 1803])
axes[1].set(title='Средний чек с картой лояльности')
axes[1].xaxis.set_major_locator(ticker.MultipleLocator(100))
axes[1].get_yaxis().set_visible(False)

fig.set_figwidth(15)
fig.set_figheight(12)

plt.show()

# %% [markdown]
# **Вывод:** По рисункам видно, что средний чек покупателей с картой лояльности ниже, чем у покупателей без карты

# %% [markdown]
# #### LTV

# %% [markdown]
# Посмотрим на график распределения LTV, чтобы выявить аномалии.

# %%
plt.scatter(y=profiles.index, x=profiles.ltv, alpha=0.3, s=10)
plt.show()

# %% [markdown]
# Отбросим все, что больше 95 перцентиля

# %%
print(np.percentile(profiles['ltv'], [95, 99]))
# Out:
# [ 4231.975 16864.072]

# %%
#создаем фильтр
query_column = profiles.ltv
query_variable = 4232
profiles_ltv = profiles.query('@query_column < @query_variable')

# %%
#неотфильтрованные данные
sample_ltv_0 = profiles[profiles['promo'] == 0]['ltv']
sample_ltv_1 = profiles[profiles['promo'] == 1]['ltv']

# %%
#отфильтрованные данные
filtered_sample_ltv_0 = profiles_ltv[profiles_ltv['promo'] == 0]['ltv']
filtered_sample_ltv_1 = profiles_ltv[profiles_ltv['promo'] == 1]['ltv']

# %% [markdown]
# Посмотрим на визуализацию.

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)
#покупатели без карты лояльности
axes[0].scatter(y=profiles[profiles['promo'] == 0].index,
           x=profiles[profiles['promo'] == 0].ltv,
           alpha=0.5, s=10)
#линия среднего
axes[0].axvline(x=round(sample_ltv_0.mean(), 2), color='red', linestyle='--')
axes[0].axvline(x=round(filtered_sample_ltv_0.mean(), 2), color='pink', linestyle='--')

#покупатели с картой лояльности
axes[1].scatter(y=profiles[profiles['promo'] == 1].index,
           x=profiles[profiles['promo'] == 1].ltv,
           alpha=0.5, s=10)
#линия среднего
axes[1].axvline(x=round(sample_ltv_1.mean(), 2), color='red', linestyle='--')
axes[1].axvline(x=round(filtered_sample_ltv_1.mean(), 2), color='pink', linestyle='--')
axes[1].axvline(x=round(old_profiles[old_profiles['promo'] == 1]['ltv'].mean(), 2), color='blue', linestyle='--')

axes[0].grid(visible=True)
axes[0].set_xlim([0, 4232]) #ограничиваем, чтобы график был читаемым
axes[0].set(title='Lifetime value без карты лояльности')
axes[0].xaxis.set_major_locator(ticker.MultipleLocator(250))
axes[0].get_yaxis().set_visible(False) #прячем id пользователей, они нам не нужны

axes[1].grid(visible=True)
axes[1].set_xlim([0, 4232])
axes[1].set(title='Lifetime value с картой лояльности')
axes[1].xaxis.set_major_locator(ticker.MultipleLocator(250))
axes[1].get_yaxis().set_visible(False)

fig.set_figwidth(15)
fig.set_figheight(12)

plt.show()

# %% [markdown]
# **Вывод:** В обоих случаях видим, что lifetime value держателей карты лояльности выше.

# %% [markdown]
# ### Проверка по неотфильтрованным данным

# %% [markdown]
# #### Гипотеза о среднем чеке

# %% [markdown]
# Применим непараметрический тест Уилкоксона-Манна-Уитни stats.mannwhitneyu(), чтобы защититься от выбросов в данных которые мы видели на графиках. Тест работает с рангами, а не с самими значениями, и сможет показать статистическую значимость даже если данные распределены ненормально.

# %% [markdown]
# Гипотеза о среднем чеке
# - $H_{0}$: Между чеками участников программы лояльности и остальными покупателями **нет** значимой разницы.
# - $H_{1}$: Между чеками участников программы лояльности и остальными покупателями **есть** значимая разница.

# %%
#считаем статистическую значимость различий в среднем чеке покупателя между группами
print("p-value: {0:.3f}".format(stats.mannwhitneyu(sample_check_0, sample_check_1)[1]))
#выводим средние показатели
print("Среднее среднего чека без карты лояльности: {:.2f}".format(sample_check_0.mean()))
print("Среднее среднего чека с картой лояльности: {:.2f}".format(sample_check_1.mean()))
#считаем относительную разницу в среднем чеке покупателя между группами
print("Относительная разница: {0:.2%}".format(sample_check_0.mean() / sample_check_1.mean() - 1))
# Out:
# p-value: 0.002
# Среднее среднего чека без карты лояльности: 718.61
# Среднее среднего чека с картой лояльности: 561.53
# Относительная разница: 27.97%

# %% [markdown]
# **Вывод:** p-value меньше 0.05, поэтому нулевую гипотезу отвергаем. Группы отличаются на 28%. Статистически значимые различия в среднем чеке между группами есть.

# %% [markdown]
# #### Гипотеза о lifetime value

# %% [markdown]
# Гипотеза о lifetime value
# - $H_{0}$: Между lifetime value участников программы лояльности и остальными покупателями **нет** значимой разницы.
# - $H_{1}$: Между lifetime value  участников программы лояльности и остальными покупателями **есть** значимая разница.

# %%
#считаем статистическую значимость различий в lifetime value покупателя между группами
print("p-value: {0:.3f}".format(stats.mannwhitneyu(sample_ltv_0, sample_ltv_1)[1]))
#выводим средние показатели
print("Среднее lifetimevalue без карты лояльности: {:.2f}".format(sample_ltv_0.mean()))
print("Среднее lifetimevalue с картой лояльности: {:.2f}".format(sample_ltv_1.mean()))
#считаем относительную разницу в lifetime value покупателя между группами
print("Относительная разница: {0:.2%}".format(sample_ltv_1.mean() / sample_ltv_0.mean() - 1))
# Out:
# p-value: 0.000
# Среднее lifetimevalue без карты лояльности: 1459.64
# Среднее lifetimevalue с картой лояльности: 1563.68
# Относительная разница: 7.13%

# %% [markdown]
# **Вывод:** p-value меньше 0.05, поэтому нулевую гипотезу отвергаем. Группы отличаются на 7%. Статистически значимые различия в lifetime value между группами есть.

# %% [markdown]
# **Примечание:** Разница между средними групп есть, но статистический тест почему-то ее не показывает.

# %% [markdown]
# ### Проверка по отфильтрованным данным

# %% [markdown]
# #### Гипотеза о среднем чеке

# %% [markdown]
# Гипотеза о среднем чеке
# - $H_{0}$: Между чеками участников программы лояльности и остальными покупателями **нет** значимой разницы.
# - $H_{1}$: Между чеками участников программы лояльности и остальными покупателями **есть** значимая разница.

# %%
#считаем статистическую значимость различий в среднем чеке покупателя между отфильтрованными группами
print("p-value: {0:.3f}".format(stats.mannwhitneyu(filtered_sample_check_0, filtered_sample_check_1)[1]))
#выводим средние показатели
print("Среднее среднего чека без карты лояльности: {:.2f}".format(filtered_sample_check_0.mean()))
print("Среднее среднего чека с картой лояльности: {:.2f}".format(filtered_sample_check_1.mean()))
#считаем относительную разницу в среднем чеке покупателя между группами
print("Относительная разница: {0:.2%}".format(filtered_sample_check_0.mean() / filtered_sample_check_1.mean() - 1))
# Out:
# p-value: 0.002
# Среднее среднего чека без карты лояльности: 564.41
# Среднее среднего чека с картой лояльности: 472.81
# Относительная разница: 19.37%

# %% [markdown]
# **Вывод:** p-value меньше 0.05, поэтому нулевую гипотезу отвергаем. Группы отличаются на 19%. Статистически значимые различия в среднем чеке между группами есть. Однако, и по явному сравнению средних и по графикам выше можно сказать, что средний чек участников программы лояльности **ниже**, чем у остальных покупателей.

# %% [markdown]
# #### Гипотеза о lifetime value

# %% [markdown]
# Гипотеза о lifetime value
# - $H_{0}$: Между lifetime value участников программы лояльности и остальными покупателями **нет** значимой разницы.
# - $H_{1}$: Между lifetime value  участников программы лояльности и остальными покупателями **есть** значимая разница.

# %%
#считаем статистическую значимость различий в lifetime value покупателя между группами
print("p-value: {0:.3f}".format(stats.mannwhitneyu(filtered_sample_ltv_0, filtered_sample_ltv_1)[1]))
#выводим средние показатели
print("Среднее lifetimevalue без карты лояльности: {:.2f}".format(filtered_sample_ltv_0.mean()))
print("Среднее lifetimevalue с картой лояльности: {:.2f}".format(filtered_sample_ltv_1.mean()))
#считаем относительную разницу в lifetime value покупателя между группами
print("Относительная разница: {0:.2%}".format(filtered_sample_ltv_1.mean() / filtered_sample_ltv_0.mean() - 1))
# Out:
# p-value: 0.000
# Среднее lifetimevalue без карты лояльности: 753.73
# Среднее lifetimevalue с картой лояльности: 1081.26
# Относительная разница: 43.45%

# %% [markdown]
# **Вывод:** p-value меньше 0.05, поэтому нулевую гипотезу отвергаем. Группы отличаются на 43%. Статистически значимые различия в lifetime value между группами есть. Тут же наоборот видно, что lifetime value участников программы лояльности **выше**, чем у остальных покупателей.

# %% [markdown]
# ## Вывод и рекомендации для заказчика

# %% [markdown]
# **Общие выводы по итогам исследования:**
# - Средний чек участников программы лояльности **ниже**, чем у остальных в среднем на 19%.
# - Однако, lifetime value участников программы **выше**, чем у остальных в среднем на 43%.
# - 42% выручки среди участников программы составляет оплата за участие в программе ней.
# - Участники программы совершают 99% всех покупок в одном магазине, при этом остальные совершают там только 86%. Если одной из задач программы лояльности являлось познакомить клиента с **сетью** магазинов, то она с ней точно не справилась.
# - Товарные позиции, которые наиболее популярны и среди участников программы и среди других покупателей:
#     1. 85123A
#     2. 85099B
#     3. 22469
#     4. 22423
#     5. 22720
#
# **Рекомендации:**
# - Программу лояльности нужно сократить только до самых популярных товарных позиций.
# - Прямо сейчас программа показывает плюс только из-за ее стоимости. Если в анализ включить расходы на эту самую программу, то может оказаться, что она работает в минус.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Откройте-файл-с-данными-и-изучите-общую-информацию" data-toc-modified-id="Откройте-файл-с-данными-и-изучите-общую-информацию-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Откройте файл с данными и изучите общую информацию</a></span></li><li><span><a href="#Подготовьте-данные" data-toc-modified-id="Подготовьте-данные-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовьте данные</a></span><ul class="toc-item"><li><span><a href="#Замените-названия-столбцов-(приведите-к-нижнему-регистру)" data-toc-modified-id="Замените-названия-столбцов-(приведите-к-нижнему-регистру)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Замените названия столбцов (приведите к нижнему регистру)</a></span></li><li><span><a href="#Преобразуйте-данные-в-нужные-типы.-Опишите,-в-каких-столбцах-заменили-тип-данных-и-почему" data-toc-modified-id="Преобразуйте-данные-в-нужные-типы.-Опишите,-в-каких-столбцах-заменили-тип-данных-и-почему-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему</a></span></li><li><span><a href="#Обработайте-пропуски-при-необходимости" data-toc-modified-id="Обработайте-пропуски-при-необходимости-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обработайте пропуски при необходимости</a></span><ul class="toc-item"><li><span><a href="#Объясните,-почему-заполнили-пропуски-определённым-образом-или-почему-не-стали-это-делать" data-toc-modified-id="Объясните,-почему-заполнили-пропуски-определённым-образом-или-почему-не-стали-это-делать-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Объясните, почему заполнили пропуски определённым образом или почему не стали это делать</a></span></li><li><span><a href="#Опишите-причины,-которые-могли-привести-к-пропускам" data-toc-modified-id="Опишите-причины,-которые-могли-привести-к-пропускам-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Опишите причины, которые могли привести к пропускам</a></span></li><li><span><a href="#Обратите-внимание-на-аббревиатуру-'tbd'-в-столбце-с-оценкой-пользователей.-Отдельно-разберите-это-значение-и-опишите,-как-его-обработать" data-toc-modified-id="Обратите-внимание-на-аббревиатуру-'tbd'-в-столбце-с-оценкой-пользователей.-Отдельно-разберите-это-значение-и-опишите,-как-его-обработать-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать</a></span></li></ul></li><li><span><a href="#Посчитайте-суммарные-продажи-во-всех-регионах-и-запишите-их-в-отдельный-столбец." data-toc-modified-id="Посчитайте-суммарные-продажи-во-всех-регионах-и-запишите-их-в-отдельный-столбец.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.</a></span></li></ul></li><li><span><a href="#Проведите-исследовательский-анализ-данных" data-toc-modified-id="Проведите-исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li><li><span><a href="#Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span></li><li><span><a href="#Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы." data-toc-modified-id="Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.</a></span></li><li><span><a href="#Соотнесите-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Соотнесите-выводы-с-продажами-игр-на-других-платформах.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Соотнесите выводы с продажами игр на других платформах.</a></span></li><li><span><a href="#Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?</a></span></li></ul></li><li><span><a href="#Составьте-портрет-пользователя-каждого-региона-(NA,-EU,-JP)" data-toc-modified-id="Составьте-портрет-пользователя-каждого-региона-(NA,-EU,-JP)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Составьте портрет пользователя каждого региона (NA, EU, JP)</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-каждого-региона-(топ-5).-Опишите-различия-в-долях-продаж." data-toc-modified-id="Самые-популярные-платформы-каждого-региона-(топ-5).-Опишите-различия-в-долях-продаж.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Самые популярные платформы каждого региона (топ-5). Опишите различия в долях продаж.</a></span></li><li><span><a href="#Самые-популярные-жанры-каждого-региона-(топ-5).-Поясните-разницу." data-toc-modified-id="Самые-популярные-жанры-каждого-региона-(топ-5).-Поясните-разницу.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Самые популярные жанры каждого региона (топ-5). Поясните разницу.</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li></ul></li><li><span><a href="#Проверьте-гипотезы" data-toc-modified-id="Проверьте-гипотезы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверьте гипотезы</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые." data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные." data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.</a></span></li><li><span><a href="#Поясните,-как-вы-сформулировали-нулевую-и-альтернативную-гипотезы." data-toc-modified-id="Поясните,-как-вы-сформулировали-нулевую-и-альтернативную-гипотезы.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Поясните, как вы сформулировали нулевую и альтернативную гипотезы.</a></span></li><li><span><a href="#Поясните,-какой-критерий-применили-для-проверки-гипотез-и-почему." data-toc-modified-id="Поясните,-какой-критерий-применили-для-проверки-гипотез-и-почему.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Поясните, какой критерий применили для проверки гипотез и почему.</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Введение

# %% [markdown]
# **Название проекта:** \
# Аналитика закономерностей, определяющих успешность компьютерных игр.
#
# **Описание проекта:** \
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы. Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# **Цели проекта:** \
# Нам предстоит изучить:
# - популярность игровых платформ и жанров
# - оценки пользователей и критиков
# - портрет пользователя из разных регионов
#
# Чтобы в итоге у нас получилось:
# - узнать самые популярные жанры/платформы в каждом регионе
# - узнать повлияют ли оценки пользователей на продажи игры
#
# **Исходные данные:** \
# `Name` — название игры \
# `Platform` — платформа \
# `Year_of_Release` — год выпуска \
# `Genre` — жанр игры \
# `NA_sales` — продажи в Северной Америке (миллионы проданных копий) \
# `EU_sales` — продажи в Европе (миллионы проданных копий) \
# `JP_sales` — продажи в Японии (миллионы проданных копий) \
# `Other_sales` — продажи в других странах (миллионы проданных копий) \
# `Critic_Score` — оценка критиков (максимум 100) \
# `User_Score` — оценка пользователей (максимум 10) \
# `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
#
# **План анализа данных:**
# 1. Подготовить исходные данные к анализу
# 2. Провести пользовательский анализ данных
# 3. Составить портрет пользователя в каждом регионе
# 4. Проверить гипотезы
# 5. Сформулировать выводы для отдела продаж

# %% [markdown]
# ## Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import stats as st
import warnings
import missingno as msno

# %%
try:
    df = pd.read_csv('/Users/nikitalaletin/Downloads/games.csv')
except:
    df = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# Не будем трогать оригинальный датасет, сделаем новый датасет data, чтобы первоначальные данные были целыми

# %%
data = df

# %% [markdown]
# **Пояснение:** Могу отметить, что значительные пропуски есть только в оценках пользователей/критиков и возрастном рейтинге. Еще меня смущает формат года как дробного числа, и текстовый формат оценок пользователей.

# %% [markdown]
# ## Подготовьте данные

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру)

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему

# %%
#смотрим сколько пропусков
data['year_of_release'].isna().sum()
# Out:
# 269

# %%
#удалим пропуски, чтобы не мешали конвертировать, их порядка 2%
data = data.dropna(subset=['year_of_release'])

# %%
#игнорируем предупреждения
warnings.filterwarnings("ignore")
#конвертируем
data['year_of_release'] = data['year_of_release'].astype('int')

# %% [markdown]
# ### Обработайте пропуски при необходимости

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         6607
# rating             6678
# dtype: int64

# %% [markdown]
# #### Объясните, почему заполнили пропуски определённым образом или почему не стали это делать

# %% [markdown]
# **Пояснение:**
# - Пропуски в годах выпуска удалил, потому что их незначительно мало.
# - Пропуски в оценках пользователей/критиков не стал трогать, потому что не считаю заполнение медианой уместным, а других причин (и, соотвественно, решений) кроме отсутствующих данных я не вижу
# - С пропусками в возрастном рейтинге поступил точно также. Не стал трогать, еще и потому, что здесь значение категориальное.

# %% [markdown]
# #### Опишите причины, которые могли привести к пропускам

# %% [markdown]
# Обращаемся к первоначальным данным, и пытаемся найти почему не были заполнены года выпуска.

# %%
df.loc[df['rating'].isna() == True, ['name', 'platform', 'genre', 'year_of_release']].head(10)
# Out:
#                              name platform         genre  year_of_release
# 1               Super Mario Bros.      NES      Platform           1985.0
# 4        Pokemon Red/Pokemon Blue       GB  Role-Playing           1996.0
# 5                          Tetris       GB        Puzzle           1989.0
# 9                       Duck Hunt      NES       Shooter           1984.0
# 10                     Nintendogs       DS    Simulation           2005.0
# 12    Pokemon Gold/Pokemon Silver       GB  Role-Playing           1999.0
# 18              Super Mario World     SNES      Platform           1990.0
# 20  Pokemon Diamond/Pokemon Pearl       DS  Role-Playing           2006.0
# 21               Super Mario Land       GB      Platform           1989.0
# 22            Super Mario Bros. 3      NES      Platform           1988.0

# %% [markdown]
# **Пояснение:** Посмотрев не только первые 10 строчек, затрудняюсь сказать, почему не были заполнены года выпуска игр, оценки критиков или игроков, а также рейтинг возрастной категории.

# %% [markdown]
# #### Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать

# %%
#считаем сколько таких значений на датасет
data.loc[data['user_score'] == 'tbd', 'name'].count()
# Out:
# 2376

# %%
data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce', downcast='float')

# %% [markdown]
# **Пояснение:** Гугл подсказывает, что tbd означает 'to be determined' - дословно, оценку еще 'предстоит определить'. Поэтому заменим значения tbd на NaN

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
data['world_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %% [markdown]
# ## Проведите исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
#смотрим сколько было выпущено игр по годам с помощью визуализации
(data
.pivot_table(index='year_of_release', values='world_sales', aggfunc='sum')
.plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %%
#делаем срез по году
good_data = data.query('year_of_release > 1995')

# %%
#смотрим сколько % осталось
print(good_data['year_of_release'].count() / data['year_of_release'].count() * 100, '%')
# Out:
# 95.70108233004986 %

# %% [markdown]
# **Вывод:** Оставляем только игры, которые выходили позже 1995 года.

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
#построим сводную таблицу по всем суммам продаж на всех платформах и к ней добавим график
top_sales_platforms = (
    good_data
    .pivot_table(index='platform', values='world_sales', aggfunc='sum')
    .sort_values(by='world_sales', ascending=False))
top_sales_platforms.plot(kind='bar', grid=True, figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='platform'>

# %% [markdown]
# Уберем из нашего среза плохо продающиеся платформы

# %%
#создадим список и срез по самым плохо продаваемым платформам, чтобы удалить их
#а также убедимся, что не удаляем много данных
bad_platform_list = ['PCFX', 'NG', 'WS', 'DC', 'SNES', 'SAT']
temp_query = top_sales_platforms.query('platform in @bad_platform_list')
print(sum(temp_query['world_sales']) / sum(top_sales_platforms['world_sales']) * 100, '%')
good_data = good_data.query('platform not in @bad_platform_list')
good_data = good_data.reset_index(drop=True)
# Out:
# 0.6602378393388202 %

# %% [markdown]
# Сделаем столбчатый график для первых пяти платформ

# %%
good_platforms_list = ['PS2', 'X360', 'PS3', 'Wii', 'DS']

# %%
#напишем цикл, чтобы вывести все сразу
for good_platform in good_platforms_list:
    platform_query = good_data.loc[good_data['platform'] == good_platform]
    (platform_query
     .pivot_table(index='year_of_release', values='world_sales', aggfunc='sum')
     .plot(kind='bar', grid=True, figsize=(15,5))).set_title(good_platform)

# %%
#делаем срез по платформе
platform_query = good_data.query('platform == "PC"')
#строим распределение по годам
(platform_query
.pivot_table(index='year_of_release', values='world_sales', aggfunc='sum')
.plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %%
print(sum(platform_query['world_sales']) / sum(good_data['world_sales']) * 100, '%')
# Out:
# 2.939653311336995 %

# %% [markdown]
# **Пояснение:** Любопытная платформа PC существует очень давно и все еще пользуется спросом, но составляет лишь 3% от мировых продаж

# %% [markdown]
# **Вывод:** Судя по платформам с наибольшими суммарными продажами, платформы появляются и исчезают за 6-8 лет.

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# **Подсказка:** Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# **Подсказка:** Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# Я посмотрел на графики по каждому году, начиная с 2013, и пришел к выводу, что показательнее будет составить один обобщенный график за 2013-2016 гг, один за 2015-2016 год и один график для наглядности распределения продаж почти по всем годам.

# %%
top_sales_from_1995 = (data
    .query('year_of_release > 1995')
    .pivot_table(index='platform', values='world_sales', aggfunc='sum')
    .sort_values(by='world_sales', ascending=False)
    .plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %% [markdown]
# 2015-2016 гг.

# %%
top_sales_2015_2016 = (good_data
    .query('year_of_release >= 2015')
    .pivot_table(index='platform', values='world_sales', aggfunc='sum')
    .sort_values(by='world_sales', ascending=False)
    .plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %% [markdown]
# 2013-2016 гг.

# %%
top_sales_2013_2016 = (good_data
    .query('year_of_release >= 2013')
    .pivot_table(index='platform', values='world_sales', aggfunc='sum')
    .sort_values(by='world_sales', ascending=False)
    .plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %% [markdown]
# **Пояснение:** У нас наметились явные лидеры среди платформ. Это PS4, PS3, XOne, 3DS, X360, WiiU.
# <br>
# Учитывая вывод выше, о том что платформа появляется и исчезает за 6-8 лет, посмотрим жизнеспособность этих платформ.

# %%
recently_good_platforms_list = ['PS4', 'PS3', 'XOne', '3DS', 'X360', 'WiiU']

# %%
#напишем цикл, чтобы вывести все сразу
for good_platform in recently_good_platforms_list:
    platform_query = good_data.loc[good_data['platform'] == good_platform]
    (platform_query
     .pivot_table(index='year_of_release', values='world_sales', aggfunc='sum')
     .plot(kind='bar', grid=True, figsize=(15,5))).set_title(good_platform)

# %% [markdown]
# **Вывод:** Как и подтверждается графиками, по продажам лидируют PS4, XOne и 3DS, хотя последняя платформа уже на исходе популярности, а PS3 и X360 уже не пользуются былым спросом. Также достойны упоминания платформы WiiU и PC

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
top_sales_platforms = good_data.query("platform in ['PS4', 'PS3', 'X360', 'XOne', '3DS']")

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=top_sales_platforms, x='platform', y='world_sales')\
.set(title='Продажи по платформам', xlabel='Платформы', ylabel='Продажи игр, млн.копий', ylim=(0,2))
plt.show()

# %% [markdown]
# **Вывод:** На графике видим, что медианные продажи у более старых платформ были выше, чем у более новых. Какого-то генерального вывода по этому графику сделать не могу.

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# Возьмем платформу PS4, как самую популярную за последнее время.

# %%
ps4_query = good_data.query('platform == "PS4"')
print(ps4_query['world_sales'].corr(ps4_query['user_score']))
print(ps4_query['world_sales'].corr(ps4_query['critic_score']))
# Out:
# -0.03195710900518831
# 0.40656790206178145

# %%
ps4_query.plot(kind='scatter', x='user_score', y='world_sales', grid=True, figsize=(15,5), alpha=0.5)
plt.show()

# %%
ps4_query.plot(kind='scatter', x='critic_score', y='world_sales', grid=True, figsize=(15,5), alpha=0.5)
plt.show()

# %% [markdown]
# **Вывод:** Средняя корреляция видна между продажами и оценками критиков. График рассеивания это подтверждает. Корреляции между оценками пользователей и продажами - не обнаружено.

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %% [markdown]
# Возьмем для наглядности графики еще двоих лидеров и посмотрим корреляцию и для других платформ

# %%
xone_query = good_data.query('platform == "XOne"')
print(xone_query['world_sales'].corr(xone_query['user_score']))
print(xone_query['world_sales'].corr(xone_query['critic_score']))
# Out:
# -0.06892505319711217
# 0.4169983280084016

# %%
xone_query.plot(kind='scatter', x='user_score', y='world_sales', grid=True, figsize=(15,5), alpha=0.5)
plt.show()

# %%
xone_query.plot(kind='scatter', x='critic_score', y='world_sales', grid=True, figsize=(15,5), alpha=0.5)
plt.show()

# %%
_3ds_query = good_data.query('platform == "3DS"')
print(_3ds_query['world_sales'].corr(_3ds_query['user_score']))
print(_3ds_query['world_sales'].corr(_3ds_query['critic_score']))
# Out:
# 0.22207840807969956
# 0.34873973059848346

# %%
_3ds_query.plot(kind='scatter', x='user_score', y='world_sales', grid=True, figsize=(15,5), alpha=0.5)
plt.show()

# %%
_3ds_query.plot(kind='scatter', x='critic_score', y='world_sales', grid=True, figsize=(15,5), alpha=0.5)
plt.show()

# %%
ps3_query = good_data.query('platform == "PS3"')
print(ps3_query['world_sales'].corr(ps3_query['user_score']))
print(ps3_query['world_sales'].corr(ps3_query['critic_score']))
# Out:
# 0.1284156326014225
# 0.4327589578997141

# %%
x360_query = good_data.query('platform == "X360"')
print(x360_query['world_sales'].corr(x360_query['user_score']))
print(x360_query['world_sales'].corr(x360_query['critic_score']))
# Out:
# 0.11418661762928545
# 0.3928658925400703

# %%
pc_query = good_data.query('platform == "3DS"')
print(pc_query['world_sales'].corr(pc_query['user_score']))
print(pc_query['world_sales'].corr(pc_query['critic_score']))
# Out:
# 0.22207840807969956
# 0.34873973059848346

# %% [markdown]
# **Вывод:** Средняя корреляция и тут есть между продажами и оценками критиков. А графики рассеивания это подтверждают. Корреляции между оценками пользователей и продажами если и встречается, то достаточно слабая.

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# Посмотрим какие вообще бывают жанры

# %%
good_data['genre'].value_counts()
# Out:
# Action          3209
# Sports          2180
# Misc            1670
# Role-Playing    1378
# Adventure       1235
# Shooter         1204
# Racing          1183
# Simulation       824
# Platform         785
# Fighting         733
# Strategy         624
# Puzzle           514
# Name: genre, dtype: int64

# %%
(good_data
    .pivot_table(index='genre', values='world_sales', aggfunc='sum')
    .sort_values(by='world_sales', ascending=False)
    .plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %%
genre_rating = (
    good_data
    .pivot_table(index='genre', values='world_sales', aggfunc=['sum', 'count', 'median'])
    .sort_values(by=('median', 'world_sales'), ascending=False)
)
genre_rating
# Out:
#                      sum       count      median
#              world_sales world_sales world_sales
# genre
# Shooter           961.95        1204        0.24
# Platform          586.50         785        0.23
# Sports           1241.85        2180        0.22
# Fighting          382.91         733        0.21
# Action           1639.99        3209        0.18
# Racing            682.66        1183        0.18
# Role-Playing      864.18        1378        0.17
# Misc              766.29        1670        0.16
# Simulation        373.93         824        0.15
# Puzzle            153.97         514        0.09
# Strategy          156.16         624        0.09
# Adventure         203.14        1235        0.05

# %% [markdown]
# И то же самое, но за последние несколько лет, возможно популярные жанры изменились.

# %%
(good_data
    .query('year_of_release > 2012')
    .pivot_table(index='genre', values='world_sales', aggfunc='sum')
    .sort_values(by='world_sales', ascending=False)
    .plot(kind='bar', grid=True, figsize=(15,5)))
plt.show()

# %% [markdown]
# **Вывод:** Самый продаваемый жанр - Action, однако, игр этого жанра и выходит больше всех. Самыми стабильно прибыльным жанрами я бы назвал Shooter, Platform, Sports, Fighting, и на пятом месте - Action.

# %% [markdown]
# ## Составьте портрет пользователя каждого региона (NA, EU, JP)

# %% [markdown]
# ### Самые популярные платформы каждого региона (топ-5). Опишите различия в долях продаж.

# %% [markdown]
# Напишем функции для всех трех регионов

# %%
#функция для визуализации самой популярной платформы в виде столбчатого графика
def top_regional_platforms_barplot(regional_sales):
    top_platforms = (
        good_data
        .pivot_table(index='platform', values=regional_sales, aggfunc='sum')
        .sort_values(by=regional_sales, ascending=False)
    )
    return top_platforms.plot(kind='bar', grid=True, figsize=(15,5))

# %%
#функция для визуализации самой популярной платформы в виде круговой диаграммы
def top_regional_platforms_piechart(regional_sales):
    top_platforms = (
        good_data
        .pivot_table(index='platform', values=regional_sales, aggfunc='sum')
        .sort_values(by=regional_sales, ascending=False)
    )
    return top_platforms.plot(subplots=True, kind='pie', grid=True, figsize=(10,10))
#я ее пробовал применить, но результат не очень красивый

# %%
#функция для просмотра точных цифр продаж по платформе каждого региона
def top_regional_platforms_table(regional_sales):
    top_platforms = (
        good_data
        .pivot_table(index='platform', values=regional_sales, aggfunc=['sum', 'count', 'median'])
        .droplevel(level=1, axis=1)
        .sort_values(by=('sum'), ascending=False)
    )
    return top_platforms

# %% [markdown]
# Самые популярные платформы Северной Америки

# %%
top_regional_platforms_barplot('na_sales')
plt.show()

# %%
top_regional_platforms_na = top_regional_platforms_table('na_sales')
top_regional_platforms_na = top_regional_platforms_na.rename(columns={'sum': 'na_sum',
                                                                      'count': 'na_count',
                                                                      'median': 'na_median'})
top_regional_platforms_na
# Out:
#           na_sum  na_count  na_median
# platform
# X360      595.74      1232       0.18
# PS2       572.92      2127       0.09
# Wii       486.87      1286       0.13
# PS3       390.13      1306       0.12
# DS        380.31      2120       0.06
# PS        318.35      1074       0.09
# GBA       184.12       811       0.10
# XB        182.06       803       0.11
# N64       138.91       316       0.19
# GC        131.94       542       0.11
# PS4       108.74       392       0.06
# PSP       107.27      1193       0.00
# XOne       93.12       247       0.12
# PC         84.80       942       0.00
# 3DS        82.65       512       0.01
# GB         49.52        60       0.00
# WiiU       38.10       147       0.11
# PSV        12.47       429       0.00

# %% [markdown]
# Топ-5 платформ Северной Америки.
# 1. X360
# 2. PS2
# 3. Wii
# 4. PS3
# 5. DS

# %% [markdown]
# Самые популярные платформы Европы

# %%
top_regional_platforms_barplot('eu_sales')
plt.show()

# %%
top_regional_platforms_eu = top_regional_platforms_table('eu_sales')
top_regional_platforms_eu = top_regional_platforms_eu.rename(columns={'sum': 'eu_sum',
                                                                      'count': 'eu_count',
                                                                      'median': 'eu_median'})
top_regional_platforms_eu
# Out:
#           eu_sum  eu_count  eu_median
# platform
# PS2       332.63      2127       0.05
# PS3       327.21      1306       0.06
# X360      268.32      1232       0.05
# Wii       258.32      1286       0.01
# PS        201.34      1074       0.06
# DS        188.41      2120       0.00
# PS4       141.09       392       0.08
# PC        129.54       942       0.03
# GBA        74.59       811       0.04
# PSP        65.62      1193       0.00
# 3DS        61.27       512       0.00
# XB         59.65       803       0.03
# XOne       51.59       247       0.07
# N64        41.03       316       0.04
# GC         38.32       542       0.03
# GB         31.37        60       0.00
# WiiU       25.13       147       0.07
# PSV        13.07       429       0.00

# %% [markdown]
# Топ-5 платформ Европы.
# 1. PS2
# 2. PS3
# 3. X360
# 4. Wii
# 5. PS

# %% [markdown]
# Самые популярные платформы Японии

# %%
top_regional_platforms_barplot('jp_sales')
plt.show()

# %%
top_regional_platforms_jp = top_regional_platforms_table('jp_sales')
top_regional_platforms_jp = top_regional_platforms_jp.rename(columns={'sum': 'jp_sum',
                                                                      'count': 'jp_count',
                                                                      'median': 'jp_median'})
top_regional_platforms_jp
# Out:
#           jp_sum  jp_count  jp_median
# platform
# DS        175.00      2120       0.00
# PS2       137.54      2127       0.00
# PS        127.57      1074       0.00
# 3DS       100.62       512       0.05
# PS3        79.41      1306       0.01
# PSP        75.88      1193       0.02
# Wii        68.28      1286       0.00
# GB         50.48        60       0.36
# GBA        46.56       811       0.00
# N64        33.76       316       0.00
# PSV        21.84       429       0.03
# GC         21.34       542       0.00
# PS4        15.96       392       0.01
# WiiU       13.01       147       0.00
# X360       12.30      1232       0.00
# XB          1.38       803       0.00
# XOne        0.34       247       0.00
# PC          0.17       942       0.00

# %% [markdown]
# Топ-5 платформ Японии.
# 1. DS
# 2. PS2
# 3. PS
# 4. 3DS
# 5. PS3

# %% [markdown]
# **Пояснение:** Не могу не отметить медианные продажи платформы GB в Японии, что говорит о высокой популярности каждой игры, когда-либо выходившей на эту платформу.

# %% [markdown]
# Совместим наши таблицы для наглядности результата

# %%
top_regional_platforms = (
    top_regional_platforms_na
    .merge(top_regional_platforms_eu, on='platform', how='inner')
)
top_regional_platforms = (
    top_regional_platforms
    .merge(top_regional_platforms_jp, on='platform', how='inner')
)

# %%
top_regional_platforms.iloc[:, [0,3,6,2,5,8,1,4,7]]
# Out:
#           na_sum  eu_sum  jp_sum  na_median  eu_median  jp_median  na_count  \
# platform
# X360      595.74  268.32   12.30       0.18       0.05       0.00      1232
# PS2       572.92  332.63  137.54       0.09       0.05       0.00      2127
# Wii       486.87  258.32   68.28       0.13       0.01       0.00      1286
# PS3       390.13  327.21   79.41       0.12       0.06       0.01      1306
# DS        380.31  188.41  175.00       0.06       0.00       0.00      2120
# PS        318.35  201.34  127.57       0.09       0.06       0.00      1074
# GBA       184.12   74.59   46.56       0.10       0.04       0.00       811
# XB        182.06   59.65    1.38       0.11       0.03       0.00       803
# N64       138.91   41.03   33.76       0.19       0.04       0.00       316
# GC        131.94   38.32   21.34       0.11       0.03       0.00       542
# PS4       108.74  141.09   15.96       0.06       0.08       0.01       392
# ...

# %% [markdown]
# **Вывод:**
# - В Северной Америке в целом больше продаж, чем в Европе и в Японии вместе, люди предпочитают XBox, а не Playstation, хотя и не торопятся переходить на новую платформу XBox
# - В Японии отдают явное предпочтение портативным платформам и PlayStation
# - В Европе люди больше играют на компьютере, по сравнению с другими рынками, а также отдают большее предпочтение PlayStation, а не XBox

# %%
top_regional_platforms_piechart('na_sales')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ### Самые популярные жанры каждого региона (топ-5). Поясните разницу.

# %% [markdown]
# Здесь тоже напишем функции сразу для всех регионов

# %%
#функция для визуализации самого популярного жанра в виде столбчатого графика
def top_regional_genres_barplot(regional_sales):
    top_genres = (
        good_data
        .pivot_table(index='genre', values=regional_sales, aggfunc='sum')
        .sort_values(by=regional_sales, ascending=False)
    )
    return top_genres.plot(kind='bar', grid=True, figsize=(15,5))

# %%
#функция для визуализации самого популярного жанра в виде круговой диаграммы
def top_regional_genres_piechart(regional_sales):
    top_genres = (
        good_data
        .pivot_table(index='genre', values=regional_sales, aggfunc='sum')
        .sort_values(by=regional_sales, ascending=False)
    )
    return top_genres.plot(subplots=True, kind='pie', grid=True, figsize=(10,10))

# %%
#функция для просмотра точных цифр продаж по жанру каждого региона
def top_regional_genres_table(regional_sales):
    top_genres = (
        good_data
        .pivot_table(index='genre', values=regional_sales, aggfunc=['sum', 'count', 'median'])
        .droplevel(level=1, axis=1)
        .sort_values(by=('sum'), ascending=False)
    )
    return top_genres

# %% [markdown]
# Самые популярные жанры Северной Америки.

# %%
top_regional_genres_barplot('na_sales')
plt.show()

# %%
top_regional_genres_table('na_sales')
# Out:
#                  sum  count  median
# genre
# Action        811.97   3209    0.10
# Sports        650.37   2180    0.11
# Shooter       526.89   1204    0.13
# Misc          390.11   1670    0.08
# Racing        339.45   1183    0.10
# Role-Playing  326.18   1378    0.05
# Platform      309.53    785    0.13
# Fighting      200.86    733    0.09
# Simulation    175.69    824    0.07
# Adventure      91.32   1235    0.00
# Puzzle         71.06    514    0.05
# Strategy       64.59    624    0.01

# %% [markdown]
# Топ-5 жанров Северной Америки.
# 1. Action
# 2. Sports
# 3. Shooter
# 4. Misc
# 5. Racing

# %% [markdown]
# **Пояснение:** Google подсказывает, что "Games that do not fall into any genre are automatically classified as Miscellaneous Games", то есть по сути, misc - это сборник совершенно разных игр, не попадающих ни под какую категорию. Соотвественно, на пятое место может претендовать Role-Playing.

# %% [markdown]
# Самые популярные жанры Европы.

# %%
top_regional_genres_barplot('eu_sales')
plt.show()

# %%
top_regional_genres_table('eu_sales')
# Out:
#                  sum  count  median
# genre
# Action        502.67   3209    0.03
# Sports        365.97   2180    0.03
# Shooter       307.75   1204    0.06
# Racing        228.25   1183    0.04
# Misc          207.32   1670    0.01
# Role-Playing  187.78   1378    0.01
# Platform      165.63    785    0.05
# Simulation    111.14    824    0.02
# Fighting       91.66    733    0.03
# Adventure      56.50   1235    0.00
# Puzzle         42.61    514    0.01
# Strategy       41.22    624    0.02

# %% [markdown]
# Топ-5 жанров Европы.
# 1. Action
# 2. Sports
# 3. Shooter
# 4. Racing
# 5. Misc

# %% [markdown]
# **Пояснение:** Тут то же самое. На пятое место может претендовать Role-Playing.

# %% [markdown]
# Самые популярные жанры Японии.

# %%
top_regional_genres_barplot('jp_sales')
plt.show()

# %%
top_regional_genres_table('jp_sales')
# Out:
#                  sum  count  median
# genre
# Role-Playing  292.75   1378    0.05
# Action        144.37   3209    0.00
# Misc           96.10   1670    0.00
# Sports         94.24   2180    0.00
# Platform       66.10    785    0.00
# Simulation     56.91    824    0.00
# Fighting       55.80    733    0.01
# Racing         40.81   1183    0.00
# Strategy       40.06    624    0.00
# Adventure      39.41   1235    0.01
# Puzzle         29.52    514    0.00
# Shooter        25.37   1204    0.00

# %% [markdown]
# Топ-5 жанров Японии.
# 1. Role-Playing
# 2. Action
# 3. Misc
# 4. Sports
# 5. Platform

# %% [markdown]
# **Пояснение:** На пятое место может претендовать жанр Simulation.

# %% [markdown]
# **Вывод:**
# - Жанрово европейский и американский рынки очень похожи
# - В Японии почти не играют в шутеры, зато очень любят ролевые игры

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# Посмотрим, какой вообще бывает ESRB рейтинг.

# %%
good_data['rating'].value_counts()
# Out:
# E       3918
# T       2892
# M       1534
# E10+    1392
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# С помощью гугла я выяснил за что отвечают буквы в рейтинге и пойду от самого низкого возраста к самому высокому:
# - E - Everyone. Игра подходит для всех возрастов
# - E10+ - Everyone 10+. Игра для возраста 10+
# - T - Teen. Игра для возраста 13+
# - М - Mature. Игра для возраста 17+
#
# Остальных значений слишком мало, чтобы уделять им внимание. Сразу сделаем срез без них, чтобы они не мешали

# %%
good_data = good_data.query("rating in ['E', 'E10+', 'T', 'M']")

# %%
#функция для визуализации возрастного рейтинга и продаж в виде столбчатого графика
def regional_ratings_barplot(regional_sales):
    regional_ratings = (
        good_data
        .pivot_table(index='rating', values=regional_sales, aggfunc='sum')
        .sort_values(by=regional_sales, ascending=False)
    )
    return regional_ratings.plot(kind='bar', grid=True, figsize=(15,5))

# %%
#функция для просмотра точных цифр продаж по возрастному рейтингу каждого региона
def regional_ratings_table(regional_sales):
    regional_ratings = (
        good_data
        .pivot_table(index='rating', values=regional_sales, aggfunc=['sum', 'median'])
        .droplevel(level=1, axis=1)
        .sort_values(by=('sum'), ascending=False)
    )
    return regional_ratings

# %% [markdown]
# Возрастные рейтинги в Северной Америке

# %%
regional_ratings_barplot('na_sales')
plt.show()

# %%
regional_ratings_table('na_sales')
# Out:
#             sum  median
# rating
# E       1273.22    0.12
# T        746.67    0.11
# M        742.87    0.14
# E10+     345.50    0.12

# %% [markdown]
# Возрастные рейтинги в Европе

# %%
regional_ratings_barplot('eu_sales')
plt.show()

# %%
regional_ratings_table('eu_sales')
# Out:
#            sum  median
# rating
# E       703.82    0.03
# M       480.00    0.09
# T       420.49    0.04
# E10+    183.33    0.03

# %% [markdown]
# Возрастные рейтинги в Японии

# %%
regional_ratings_barplot('jp_sales')
plt.show()

# %%
regional_ratings_table('jp_sales')
# Out:
#            sum  median
# rating
# E       197.71     0.0
# T       147.81     0.0
# M        63.53     0.0
# E10+     40.20     0.0

# %% [markdown]
# **Пояснение:**
# - Игры для всех возрастов пользуются одинаково высоким спросом во всех регионах
# - Игры для тинейджеров значительно популярнее в Японии, чем игры для взрослой аудитории
# - Игры для взрослой аудитории незначительно, но все же популярнее в Европе, чем игры для тинейджеров
#
# **Вывод:** Рейтинг ESRB влияет на продажи в отдельных регионах

# %% [markdown]
# ## Проверьте гипотезы

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# Выделим пользовательские рейтинги платформ Xbox One и PC в отдельные переменные и удалим пропуски

# %%
xone_user_rating = good_data.loc[good_data['platform'] == 'XOne', 'user_score'].dropna()
pc_user_rating = good_data.loc[good_data['platform'] == 'PC', 'user_score'].dropna()

# %% [markdown]
# **Формулируем гипотезы:**
#
# **H_0:** Средние пользовательские рейтинги (user_score) платформы XOne = Средние пользовательские рейтинги (user_score) платформы PC
#
# **H_1:** Средние пользовательские рейтинги (user_score) платформы XOne ≠ Средние пользовательские рейтинги (user_score) платформы PC

# %%
results = st.ttest_ind(xone_user_rating, pc_user_rating)
#проверим сразу несколько пороговых значений
alpha_1 = 0.01
alpha_2 = 0.05
alpha_3 = 0.1

print(results.pvalue)

#alpha_1
if results.pvalue < alpha_1:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
    
#alpha_2
if results.pvalue < alpha_2:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
    
#alpha_3   
if results.pvalue < alpha_3:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 2.1744530501070656e-06
# Отвергаем нулевую гипотезу
# Отвергаем нулевую гипотезу
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод:** Средние пользовательские рейтинги платформ Xbox One и PC не одинаковые.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %%
action_user_rating = good_data.loc[good_data['genre'] == 'Action', 'user_score'].dropna()
sports_user_rating = good_data.loc[good_data['genre'] == 'Sports', 'user_score'].dropna()

# %% [markdown]
# **Формулируем гипотезы:**
#
# **H_0:** Средние пользовательские рейтинги (user_score) жанра Action ≠ Средние пользовательские рейтинги (user_score) жанра Sports
#
# **H_1:** Средние пользовательские рейтинги (user_score) жанра Action = Средние пользовательские рейтинги (user_score) жанра Sports

# %%
results = st.ttest_ind(action_user_rating, sports_user_rating)
#проверим сразу несколько пороговых значений
alpha_1 = 0.01
alpha_2 = 0.05
alpha_3 = 0.1

print(results.pvalue)

#alpha_1
if results.pvalue > alpha_1:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
    
#alpha_2
if results.pvalue > alpha_2:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
    
#alpha_3   
if results.pvalue > alpha_3:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 0.11794307445170835
# Отвергаем нулевую гипотезу
# Отвергаем нулевую гипотезу
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод:** Средние пользовательские рейтинги жанров Action и Sports одинаковые.

# %% [markdown]
# ### Поясните, как вы сформулировали нулевую и альтернативную гипотезы.

# %% [markdown]
# **Пояснение:**
# <br>В случае с рейтингами платформ:
# - Нулевая гипотеза: средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# - Альтернативная гипотеза: средние пользовательские рейтинги платформ Xbox One и PC разные (более чем на 5%)
#
# В случае с рейтингами жанров:
# - Нулевая гипотеза: средние пользовательские рейтинги жанров Action и Sports разные.
# - Альтернативная гипотеза: средние пользовательские рейтинги жанров Action и Sports одинаковые. (отличия менее 5%)

# %% [markdown]
# ### Поясните, какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# **Пояснение:**
# <br>
# - В Python существует метод, который просто возвращает статистику разности между средним и тем значением, с которым мы его сравниваем (в нашем случае с другим средним).
# - Уровень значимости, на котором они находятся друг от друга - это p-value.
# <br>
# - Это вероятность получить наблюдаемый результат при условии, что нулевая гипотеза верна. Общепринятые пороговые значения — 5% и 1%. Мы же проверили пороговые значения вплоть до 10%. Тем самым убедившись, что можем или не можем отвергнуть нулевую гипотезу

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Общий вывод:**
#
# В ходе исследования мы попытались выяснить успешность игры закономерности, опираясь на следующие вопросы:
# 1. Как долго пользуется популярностью и остается актульной платформа?
# 2. Какие платформы являются лидерами прямо сейчас?
# 3. Какие жанры игр являются самыми продаваемыми?
# 4. Зависят ли продажи игры от оценок критиков и игроков?
# 5. Различаются по разным регионам продаж такие параметры как:
#     - Популярность платформы
#     - Популярность жанра
#     - Влияние возрастного рейтинга на продаваемость игры
#
# И смогли прийти к следующим выводам:
#
# **Пункт 1.** Топовые платформы пользуется популярностью примерно 6-8 лет. Исключение составляет лишь платформа PC, но на нее приходится менее 3% мировых продаж.
#
# **Пункт 2.** На 2016 Топ-5 платформ не только по продажам, но и учитывая актуальность выглядят следующим образом:
# 1. PS4
# 2. XOne
# 3. 3DS / WiiU
# 4. PS3 / X360
# 5. PC
#
# **Пункт 3.** На 2016 Топ-4 жанров не только по продажам, но и учитывая актуальность выглядят следующим образом:
# 1. Action
# 2. Shooter
# 3. Sports
# 4. Role-Playing
#
# **Пункт 4.** Наши данные показали, что продажи игры не зависят от оценок пользователей, однако оценки критиков все-таки оказывают среднее влияние на продаваемость игры.
#
# **Пункт 5.** В зависимости от региона различаются следующие параметры:
# 1. Популярность платформы.
#     - В Северной Америке в целом больше продаж, чем в Европе и в Японии вместе, люди предпочитают XBox, а не Playstation, хотя и не торопятся переходить на новую платформу XBox
#     - В Японии отдают явное предпочтение портативным платформам и PlayStation
#     - В Европе люди больше играют на компьютере, по сравнению с другими рынками, а также отдают большее предпочтение PlayStation, а не XBox
# 2. Популярность жанра.
#     - Жанрово европейский и американский рынки очень похожи
#     - В Японии почти не играют в шутеры, зато очень любят ролевые игры
# 3. Влияние возрастного рейтинга на продаваемость игры.
#     - Игры для всех возрастов пользуются одинаково высоким спросом во всех регионах
#     - Игры для тинейджеров значительно популярнее в Японии, чем игры для взрослой аудитории
#     - Игры для взрослой аудитории незначительно, но все же популярнее в Европе, чем игры для тинейджеров
#     - Как итог: рейтинг ESRB оказывает влияние на продажи в разных регионах
